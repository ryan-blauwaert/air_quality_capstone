# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import itertools
plt.style.use('seaborn-darkgrid')
palette = itertools.cycle(sns.color_palette())

# %%
air = pd.read_csv('../data/cleaned/air_all_years.csv', index_col='Year')

# %%
air
# Out:
#                      Location  CO 2nd Max 1-hr  CO 2nd Max 8-hr  \
# Year
# 1999              Albuquerque         7.500000         4.600000
# 1999                  Atlanta         6.300000         4.100000
# 1999                   Austin         2.100000         1.200000
# 1999                Baltimore        10.200000         5.600000
# 1999                   Boston         8.400000         4.200000
# ...                       ...              ...              ...
# 2018                  Wichita              NaN              NaN
# 2018           National Means         3.068182         1.909091
# 2018  National First Quartile         1.700000         1.200000
# 2018          National Median         1.900000         1.500000
# 2018  National Third Quartile         3.350000         2.250000
#
#       NO2 98th Percentile 1-hr  NO2 Mean 1-hr  Ozone 2nd Max 1-hr  \
# Year
# 1999                 54.000000      16.000000               0.100
# ...

# %%
air.index.unique()
# Out:
# Int64Index([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#             2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
#            dtype='int64', name='Year')

# %%
co_1999 = air.loc[1999, 'CO 2nd Max 1-hr']

# %%
co_2018 = air.loc[2018, 'CO 2nd Max 1-hr']

# %%
co_2018 = co_2018[~(np.isnan(co_2018))]

# %%
co_2009 = air.loc[2009, 'CO 2nd Max 1-hr']
co_2009 = co_2009[~(np.isnan(co_2009))]

# %%
co_2018
# Out:
# Year
# 2018     1.800000
# 2018     2.200000
# 2018     2.300000
# 2018     1.800000
# 2018     1.100000
# 2018     1.800000
# 2018     3.400000
# 2018     4.700000
# 2018     2.400000
# 2018     1.700000
# 2018     1.800000
# 2018     4.000000
# 2018     3.100000
# 2018     4.900000
# 2018     2.100000
# 2018     2.600000
# 2018     3.300000
# 2018     1.700000
# 2018     1.900000
# 2018     3.900000
# 2018     4.400000
# 2018     1.500000
# 2018     1.500000
# 2018     1.700000
# 2018     1.000000
# 2018    17.900000
# 2018     1.800000
# 2018     4.800000
# 2018     1.800000
# 2018     1.700000
# 2018     1.700000
# 2018     4.800000
# 2018     1.900000
# 2018     4.100000
# 2018     1.600000
# 2018     1.800000
# 2018     3.600000
# 2018     2.700000
# 2018    14.300000
# 2018     1.400000
# 2018     1.600000
# 2018     1.400000
# 2018     1.400000
# 2018     2.100000
# 2018     3.068182
# 2018     1.700000
# 2018     1.900000
# 2018     3.350000
# ...

# %%
fig, axs = plt.subplots(1,3, figsize=(12,8), sharey=True)
ax1, ax2, ax3 = axs.flatten()
ax1.boxplot(co_1999)
ax1.set_xlabel('1999', size=20)
ax2.boxplot(co_2009)
ax2.set_xlabel('2009', size=20)
ax3.boxplot(co_2018)
ax3.set_xlabel('2018', size=20)
ax1.set_ylabel('Concentration, ppm', size=20)
plt.suptitle('National Carbon Monoxide 1999, 2009, 2018', size=32)
fig.tight_layout()
plt.savefig('../images/eda_boxplot_example')
plt.show()
